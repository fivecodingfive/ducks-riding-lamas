# %%
# %matplotlib inline

# %%
# %run main_ppo.py --mode validation --episodes 100 --modelpath models/ppo_agent_104_reward22.12_actor.keras
# Out:
# 2025-07-09 09:47:49.478224: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 09:47:49.489786: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752047269.502953   13224 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752047269.506764   13224 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %matplotlib notebook

# %%
# %run main_ppo.py --mode validation --episodes 100 --modelpath models/ppo_agent_104_reward22.12_actor.keras
# Out:
# Seed set to 42
# Running on GPU
# /home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">ppo_v0_seedNone_Jul09_094754</strong> at: <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/hx5qinw0' target="_blank">https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/hx5qinw0</a><br> View project at: <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas' target="_blank">https://wandb.ai/ducks-riding-llamas/ride-those-llamas</a><br>Synced 6 W&B file(s), 0 media file(s), 4 artifact file(s) and 0 other file(s)
# ...

# %%
# %matplotlib notebook

# %%
# %run main_ppo.py --mode validation --episodes 100 --modelpath models/ppo_agent_104_reward22.12_actor.keras
# Out:
# 2025-07-09 09:54:40.070608: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 09:54:40.227734: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752047680.304930   14784 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752047680.328326   14784 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %matplotlib widget
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/miniconda3/envs/lab/lib/python3.11/site-packages/matplotlib/backends/registry.py:407, in BackendRegistry.resolve_gui_or_backend(self, gui_or_backend)
#     406 try:
# --> 407     return self.resolve_backend(gui_or_backend)
#     408 except Exception:  # KeyError ?
#
# File ~/miniconda3/envs/lab/lib/python3.11/site-packages/matplotlib/backends/registry.py:369, in BackendRegistry.resolve_backend(self, backend)
#     368 if gui is None:
# --> 369     raise RuntimeError(f"'{backend}' is not a recognised backend name")
#     371 return backend, gui if gui != "headless" else None
#
# RuntimeError: 'widget' is not a recognised backend name
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 1
# ...

# %%
# %matplotlib widget
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/miniconda3/envs/lab/lib/python3.11/site-packages/matplotlib/backends/registry.py:407, in BackendRegistry.resolve_gui_or_backend(self, gui_or_backend)
#     406 try:
# --> 407     return self.resolve_backend(gui_or_backend)
#     408 except Exception:  # KeyError ?
#
# File ~/miniconda3/envs/lab/lib/python3.11/site-packages/matplotlib/backends/registry.py:369, in BackendRegistry.resolve_backend(self, backend)
#     368 if gui is None:
# --> 369     raise RuntimeError(f"'{backend}' is not a recognised backend name")
#     371 return backend, gui if gui != "headless" else None
#
# RuntimeError: 'widget' is not a recognised backend name
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 1
# ...

# %%
# !pip install ipympl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 6.9 MB/s eta 0:00:007.3 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [ipympl]
# ...

# %%
# %matplotlib widget
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/miniconda3/envs/lab/lib/python3.11/site-packages/matplotlib/backends/registry.py:407, in BackendRegistry.resolve_gui_or_backend(self, gui_or_backend)
#     406 try:
# --> 407     return self.resolve_backend(gui_or_backend)
#     408 except Exception:  # KeyError ?
#
# File ~/miniconda3/envs/lab/lib/python3.11/site-packages/matplotlib/backends/registry.py:369, in BackendRegistry.resolve_backend(self, backend)
#     368 if gui is None:
# --> 369     raise RuntimeError(f"'{backend}' is not a recognised backend name")
#     371 return backend, gui if gui != "headless" else None
#
# RuntimeError: 'widget' is not a recognised backend name
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 1
# ...

# %%
# %matplotlib widget

# %%
# %run main_ppo.py --mode validation --episodes 100 --modelpath models/ppo_agent_104_reward22.12_actor.keras
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='Step:', max=19999), Output()), …
# Total runtime: 58.39s
#  View run <strong style="color:#cdcd00">ppo_v0_seedNone_Jul09_101946</strong> at: <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/5kinspj0' target="_blank">https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/5kinspj0</a><br> View project at: <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas' target="_blank">https://wandb.ai/ducks-riding-llamas/ride-those-llamas</a><br>Synced 6 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/wandb/run-20250709_101947-5kinspj0/logs</code>

# %%
# %run main_ppo.py --mode validation --episodes 100 --modelpath models/ppo_agent_104_reward22.12_actor.keras
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='Step:', max=19999), Output()), …
# Total runtime: 54.13s
#  View run <strong style="color:#cdcd00">ppo_v0_seedNone_Jul09_102701</strong> at: <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/9uvowg15' target="_blank">https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/9uvowg15</a><br> View project at: <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas' target="_blank">https://wandb.ai/ducks-riding-llamas/ride-those-llamas</a><br>Synced 6 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/wandb/run-20250709_102701-9uvowg15/logs</code>

# %%
import matplotlib.pyplot as plt
plt.close('all')
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/battist/miniconda3/envs/lab/lib/python3.11/tkinter/__init__.py", line 1967, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "/home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/matplotlib/backends/_backend_tk.py", line 573, in destroy
#     Gcf.destroy(self)
#   File "/home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/matplotlib/_pylab_helpers.py", line 66, in destroy
#     manager.destroy()
#   File "/home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/matplotlib/backends/_backend_tk.py", line 608, in destroy
#     delayed_destroy()
#   File "/home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/matplotlib/backends/_backend_tk.py", line 598, in delayed_destroy
#     self.window.destroy()
#   File "/home/battist/miniconda3/envs/lab/lib/python3.11/tkinter/__init__.py", line 2387, in destroy
#     self.tk.call('destroy', self._w)
# ...

# %%
# %run main_ppo.py --mode validation --episodes 20 --modelpath models/ppo_agent_104_reward22.12_actor.keras
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='Step:', max=3999), Output()), _…
# Total runtime: 14.08s
#  View run <strong style="color:#cdcd00">ppo_v0_seedNone_Jul09_104009</strong> at: <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/vq1k3zu9' target="_blank">https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/vq1k3zu9</a><br> View project at: <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas' target="_blank">https://wandb.ai/ducks-riding-llamas/ride-those-llamas</a><br>Synced 6 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/wandb/run-20250709_104009-vq1k3zu9/logs</code>

# %%
import matplotlib.pyplot as plt
plt.close('all')

# %%
# %run main_ppo.py --mode validation --episodes 20 --modelpath models/ppo_agent_104_reward22.12_actor.keras
# Out:
# 2025-07-09 10:42:01.867837: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 10:42:01.913453: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752050521.952930   24377 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752050521.960679   24377 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --mode validation --episodes 20 --modelpath models/ppo_agent_104_reward22.12_actor.keras
# Out:
# 2025-07-09 10:47:18.495922: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 10:47:18.512587: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752050838.533401   25480 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752050838.537523   25480 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --mode validation --episodes 20 --modelpath models/ppo_agent_104_reward22.12_actor.keras
# Out:
# 2025-07-09 11:52:10.176317: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 11:52:10.535189: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752054730.626614   36700 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752054730.646146   36700 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --mode validation --episodes 20 --modelpath models/ppo_agent_104_reward22.12_actor.keras
# Out:
# Seed set to 42
# Running on GPU
# /home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>./wandb/wandb/run-20250709_115659-lzi83q7f</code>
# Syncing run <strong><a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/lzi83q7f' target="_blank">ppo_v0_seedNone_Jul09_115659</a></strong> to <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
# ...

# %%
# %run main_ppo.py --mode validation --episodes 20 --modelpath models/ppo_agent_104_reward22.12_actor.keras
# Out:
# 2025-07-09 11:57:40.350251: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 11:57:40.363396: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752055060.373788   37012 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752055060.376713   37012 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --mode validation --episodes 20 --modelpath models/ppo_agent_104_reward22.12_actor.keras
# Out:
# 2025-07-09 11:58:24.726495: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 11:58:24.736727: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752055104.746727   37228 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752055104.749407   37228 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --mode validation --episodes 20 --modelpath models/ppo_agent_104_reward22.12_actor.keras
# Out:
# 2025-07-09 11:59:26.559589: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 11:59:26.569197: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752055166.579061   37452 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752055166.581739   37452 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --mode validation --episodes 20 --modelpath models/ppo_agent_104_reward22.12_actor.keras
# Out:
# 2025-07-09 12:00:15.097448: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 12:00:15.108492: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752055215.118841   37683 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752055215.121935   37683 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run visualizer.py
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='Step:', max=3999), Output()), _…

# %%
# %matplotlib widget

# %%
# %run visualizer.py
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='Step:', max=3999), Output()), _…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %run visualizer.py

# %%
# %run visualizer.py

# %%
# %run visualizer.py
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='Step:', max=3999), Output()), _…

# %%
# %matplotlib widget

# %%
# %run visualizer.py
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='Step:', max=3999), Output()), _…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget

# %%
# %run visualizer.py
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %run main_ppo.py
# Out:
# 2025-07-09 12:26:27.986439: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 12:26:28.188059: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752056788.262206     743 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752056788.282145     743 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py
# Out:
# 2025-07-09 12:28:00.497613: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 12:28:00.506919: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752056880.517001     986 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752056880.519793     986 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --mode validation --episodes 20 --modelpath models/ppo_agent_106_reward22.90_actor.keras
# Out:
# Seed set to 42
# Running on GPU
# /home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>./wandb/wandb/run-20250709_124324-d0toqiol</code>
# Syncing run <strong><a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/d0toqiol' target="_blank">ppo_v0_seedNone_Jul09_124324</a></strong> to <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
# ...

# %%
# %matplotlib widget

# %%
# %run visualizer.py
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget

# %%
# %run visualizer.py
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib inline

# %%
# %run visualizer.py

# %%
# %matplotlib widget

# %%
# %run visualizer.py
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import ipywidgets as widgets
widgets.Button(description="Test Button")
# Out:
# Button(description='Test Button', style=ButtonStyle())

# %%
import ipywidgets as widgets
from IPython.display import display

b = widgets.Button(description="Test Button")
display(b)
# Out:
# Button(description='Test Button', style=ButtonStyle())

# %%
import ipywidgets as widgets
from IPython.display import display

display(widgets.Button(description="Test Button"))
# Out:
# Button(description='Test Button', style=ButtonStyle())

# %%
# %matplotlib widget

# %%
# %run visualizer.py
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %run main_ppo.py --episodes 20
# Out:
# 2025-07-09 12:57:58.761197: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 12:57:58.963610: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752058679.040244    3176 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752058679.061319    3176 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --episodes 20
# Out:
# 2025-07-09 12:58:40.415588: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 12:58:40.423656: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752058720.433569    3426 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752058720.436333    3426 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --episodes 20
# Out:
# Seed set to 42
# Running on GPU
# /home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1752058751.815034    3426 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3307 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# wandb: Currently logged in as: pytist (ducks-riding-llamas) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>./wandb/wandb/run-20250709_125913-b2n12umd</code>
# ...

# %%
# %run main_ppo.py --episodes 20
# Out:
# 2025-07-09 13:00:38.116820: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 13:00:38.127143: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752058838.137402    4129 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752058838.140500    4129 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --episodes 30
# Out:
# 2025-07-09 13:02:20.333681: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 13:02:20.346416: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752058940.357251    4761 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752058940.360076    4761 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --episodes 30
# Out:
# Seed set to 42
# Running on GPU
# /home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Finishing previous runs because reinit is set to 'default'.
# ...

# %%
# %run main_ppo.py --episodes 30
# Out:
# 2025-07-09 13:05:20.545947: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 13:05:20.557027: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752059120.567561    5713 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752059120.570978    5713 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --episodes 30
# Out:
# 2025-07-09 13:06:02.878080: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 13:06:02.887655: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752059162.897130    6068 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752059162.899814    6068 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --episodes 100
# Out:
# Seed set to 42
# Running on GPU
# /home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Finishing previous runs because reinit is set to 'default'.
# ...

# %%
# %run main_ppo.py --mode validation --modelpath models/ppo_agent_110_reward41.05_actor.keras --episodes 20
# Out:
# Seed set to 42
# Running on GPU
# /home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>./wandb/wandb/run-20250709_131228-8lfznbkx</code>
# Syncing run <strong><a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/8lfznbkx' target="_blank">ppo_v0_seedNone_Jul09_131228</a></strong> to <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
# ...

# %%
# %matplotlib widget

# %%
# %run visualizer.py
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %run main_ppo.py --episodes 300
# Out:
# 2025-07-09 13:20:46.235678: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 13:20:46.248125: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752060046.261060    9300 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752060046.264938    9300 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --mode validation --episodes 100 --modelpath models/ppo_agent_112_reward17.87_actor.keras
# Out:
# Seed set to 42
# Running on GPU
# /home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>./wandb/wandb/run-20250709_133254-08e48w3p</code>
# Syncing run <strong><a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/08e48w3p' target="_blank">ppo_v0_seedNone_Jul09_133254</a></strong> to <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
# ...

# %%
# %matplotlib widget

# %%
# %run visualizer.py
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %run main_ppo.py
# Out:
# 2025-07-09 13:39:23.904652: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 13:39:23.918353: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752061163.929685   13166 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752061163.933107   13166 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run visualizer

# %%
# %matplotlib widget

# %%
# %run visualizer.py
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %run main_ppo.py --mode validation --episodes 100 --modelpath models/ppo_agent_112_reward17.87_actor.keras
# Out:
# 2025-07-09 14:43:17.770659: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 14:43:17.791980: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752064997.804720   20006 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752064997.808051   20006 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --mode validation --episodes 100 --modelpath models/ppo_agent_112_reward17.87_actor.keras
# Out:
# Seed set to 42
# Running on GPU
# /home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">ppo_v0_seedNone_Jul09_144326</strong> at: <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/qzta5d0s' target="_blank">https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/qzta5d0s</a><br> View project at: <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas' target="_blank">https://wandb.ai/ducks-riding-llamas/ride-those-llamas</a><br>Synced 6 W&B file(s), 0 media file(s), 4 artifact file(s) and 0 other file(s)
# ...

# %%
# %run main_ppo.py --mode validation --episodes 100 --modelpath models/ppo_agent_112_reward17.87_actor.keras
# Out:
# 2025-07-09 14:50:20.077028: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 14:50:20.091075: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752065420.103909   21632 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752065420.108752   21632 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %matplotlib widget

# %%
# %run visualizer
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %run main_ppo.py
# Out:
# 2025-07-09 15:10:14.382341: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 15:10:14.392885: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752066614.403028   24868 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752066614.405877   24868 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py
# Out:
# 2025-07-09 15:13:11.925394: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 15:13:11.937737: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752066791.947799   25596 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752066791.951248   25596 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --variant 1
# Out:
# 2025-07-09 18:54:29.614872: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 18:54:29.724852: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752080069.765597   34147 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752080069.775490   34147 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --mode validation --episodes 100 --variant 1 --modelpath models/ppo_agent_118_reward29.54_actor.keras
# Out:
# Seed set to 42
# Running on GPU
# /home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>./wandb/wandb/run-20250709_190846-h6symzky</code>
# Syncing run <strong><a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/h6symzky' target="_blank">ppo_v1_seedNone_Jul09_190846</a></strong> to <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
# ...

# %%
# %run main_ppo.py --mode validation --episodes 100 --variant 1 --modelpath models/ppo_agent_118_reward29.54_actor.keras
# Out:
# 2025-07-09 19:20:31.868096: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 19:20:32.058455: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752081632.140061   39119 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752081632.162639   39119 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --mode validation --episodes 20 --variant 1 --modelpath models/ppo_agent_118_reward29.54_actor.keras
# Out:
# 2025-07-09 19:22:19.056303: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 19:22:19.070744: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752081739.084058   39874 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752081739.087924   39874 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --mode validation --episodes 20 --variant 1 --modelpath models/ppo_agent_118_reward29.54_actor.keras
# Out:
# 2025-07-09 19:24:55.246858: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 19:24:55.256443: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752081895.266312   40584 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752081895.269340   40584 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %matplotlib widget

# %%
# %run visualizer.py
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
jupyter nbextension enable --py widgetsnbextension
# Out:
#   Cell In[4], line 1
#     jupyter nbextension enable --py widgetsnbextension
#             ^
# SyntaxError: invalid syntax

# %%
# %run visualizer.py
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import ipywidgets as widgets
from IPython.display import display

button = widgets.Button(description="Test Button")
display(button)
# Out:
# Button(description='Test Button', style=ButtonStyle())

# %%
import ipywidgets
ipywidgets.__version__
# Out:
# '8.1.7'

# %%
jupyter lab --version
# Out:
#   Cell In[8], line 1
#     jupyter lab --version
#             ^
# SyntaxError: invalid syntax

# %%
# %matplotlib widget

# %%
# %run visualizer.py
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %run main_ppo.py
# Out:
# 2025-07-09 19:55:43.551362: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 19:55:43.761914: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752083743.831545   44709 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752083743.852676   44709 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --mode validation --episodes 100 --variant 1 --modelpath models/ppo_agent_120_reward20.92_actor.keras
# Out:
# Seed set to 42
# Running on GPU
# /home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>./wandb/wandb/run-20250709_200734-dnspif2i</code>
# Syncing run <strong><a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/dnspif2i' target="_blank">ppo_v1_seedNone_Jul09_200734</a></strong> to <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
# ...

# %%
# %run main_ppo.py --variant 1
# Out:
# Seed set to 42
# Running on GPU
# /home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">ppo_v1_seedNone_Jul09_200734</strong> at: <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/dnspif2i' target="_blank">https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/dnspif2i</a><br> View project at: <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas' target="_blank">https://wandb.ai/ducks-riding-llamas/ride-those-llamas</a><br>Synced 6 W&B file(s), 0 media file(s), 4 artifact file(s) and 0 other file(s)
# ...

# %%
# %run main_ppo.py --variant 1
# Out:
# 2025-07-09 20:15:01.226815: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 20:15:01.242047: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752084901.255768   49515 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752084901.259814   49515 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --mode validation --episodes 100 --variant 1 --modelpath models/ppo_agent_124_reward30.70_actor.keras
# Out:
# Seed set to 42
# Running on GPU
# /home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>./wandb/wandb/run-20250709_202752-hwhe15gb</code>
# Syncing run <strong><a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/hwhe15gb' target="_blank">ppo_v1_seedNone_Jul09_202752</a></strong> to <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
# ...

# %%
# %matplotlib widget

# %%
# %run visualizer
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %run main_ppo.py --mode validation --episodes 100 --variant 1 --modelpath models/ppo_agent_124_reward30.70_actor.keras
# Out:
# 2025-07-09 20:36:47.093740: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 20:36:47.106494: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752086207.125034   53965 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752086207.129252   53965 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %matplotlib widget

# %%
# %run visualizer
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %run main_ppo.py --variant 1
# Out:
# 2025-07-09 20:45:10.886102: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 20:45:10.896125: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752086710.906247   55748 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752086710.909777   55748 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --mode validation --episodes 20 --variant 1 --modelpath models/ppo_agent_126_reward31.09_actor.keras
# Out:
# Seed set to 42
# Running on GPU
# /home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# creating run (0.7s)
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>./wandb/wandb/run-20250709_205638-k1k6sp9h</code>
# Syncing run <strong><a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/k1k6sp9h' target="_blank">ppo_v1_seedNone_Jul09_205638</a></strong> to <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
# ...

# %%
# %matplotlib widget

# %%
# %run visualizer
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %run main_ppo.py
# Out:
# 2025-07-09 21:02:28.149105: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 21:02:28.159167: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752087748.168805   59372 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752087748.171906   59372 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [raw]
# %run main_ppo.py --mode validation --episodes 20 --variant 1 --modelpath models/ppo_agent_128_reward39.75_actor.keras

# %%
# %run main_ppo.py --mode validation --episodes 20 --variant 1 --modelpath models/ppo_agent_128_reward39.75_actor.keras
# Out:
# 2025-07-09 21:21:15.264532: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 21:21:15.279446: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752088875.292957   62906 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752088875.296767   62906 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %matplotlib widget

# %%
# %run visualizer
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %run main_ppo.py
# Out:
# 2025-07-09 21:31:10.854823: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 21:31:10.868497: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752089470.883392   65028 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752089470.886809   65028 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --mode validation --episodes 20 --variant 1 --modelpath models/ppo_agent_130_reward98.34_actor.keras
# Out:
# Seed set to 42
# Running on GPU
# /home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>./wandb/wandb/run-20250709_214249-kudgcdwj</code>
# Syncing run <strong><a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/kudgcdwj' target="_blank">ppo_v1_seedNone_Jul09_214249</a></strong> to <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
# ...

# %%
# %matplotlib widget

# %%
# %run visualizer
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %run main_ppo.py
# Out:
# 2025-07-09 21:53:45.731408: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 21:53:45.744737: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752090825.755943   69518 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752090825.759049   69518 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --mode validation --episodes 20 --variant 1 --modelpath models/ppo_agent_132_reward165.96_actor.keras
# Out:
# Seed set to 42
# Running on GPU
# /home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>./wandb/wandb/run-20250709_220449-8lhnmg4y</code>
# Syncing run <strong><a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/8lhnmg4y' target="_blank">ppo_v1_seedNone_Jul09_220449</a></strong> to <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
# ...

# %%
# %matplotlib widget

# %%
# %run visualizer
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %run main_ppo.py
# Out:
# 2025-07-09 22:47:57.611526: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-09 22:47:57.655749: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752094077.676871   80550 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752094077.683598   80550 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --episodes 20

# %%
# %run main_ppo.py --episodes 20

# %%
print("hello")
# Out:
# hello

# %%
# %matplotlib widget

# %%
# %run visualizer.py
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %run main_ppo.py
# Out:
# 2025-07-13 16:24:40.886045: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-13 16:24:41.101542: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752416681.172893    2723 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752416681.192812    2723 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --mode validation --episodes 20 --modelpath models/ppo_agent_136_reward132.28_actor.keras
# Out:
# Seed set to 42
# Running on GPU
# /home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>./wandb/wandb/run-20250713_163647-1aaxf6ir</code>
# Syncing run <strong><a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/1aaxf6ir' target="_blank">ppo_v1_seedNone_Jul13_163647</a></strong> to <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
# ...

# %%
# %matplotlib widget

# %%
# %run visualizer
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %run main_ppo.py
# Out:
# 2025-07-13 16:44:16.036760: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-13 16:44:16.090560: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752417856.111521    3255 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752417856.118816    3255 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %matplotlib widget

# %%
# %run main_ppo.py --mode validation --episodes 20 --modelpath models/ppo_agent_138_reward147.76_actor.keras
# Out:
# Seed set to 42
# Running on GPU
# /home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>./wandb/wandb/run-20250713_165631-4qph0cyu</code>
# Syncing run <strong><a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/4qph0cyu' target="_blank">ppo_v1_seedNone_Jul13_165631</a></strong> to <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
# ...

# %%
# %matplotlib widget

# %%
# %run visualizer
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %run main_ppo.py
# Out:
# 2025-07-13 17:41:35.194429: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-13 17:41:35.254797: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752421295.279929    3750 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752421295.297714    3750 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --mode validation --episodes 20 --modelpath models/ppo_agent_140_reward163.90_actor.keras
# Out:
# Seed set to 42
# Running on GPU
# /home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>./wandb/wandb/run-20250713_175321-rwlxmy9x</code>
# Syncing run <strong><a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/rwlxmy9x' target="_blank">ppo_v1_seedNone_Jul13_175321</a></strong> to <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
# ...

# %%
# %matplotlib widget

# %%
# %run visualizer
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %run main_ppo.py
# Out:
# 2025-07-13 18:03:29.805156: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-13 18:03:29.833907: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752422609.856556    4238 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752422609.864887    4238 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %run main_ppo.py --mode validation --episodes 20 --modelpath models/ppo_agent_142_reward168.49_actor.keras
# Out:
# Seed set to 42
# Running on GPU
# /home/battist/miniconda3/envs/lab/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>./wandb/wandb/run-20250713_181457-f6k6ppv6</code>
# Syncing run <strong><a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas/runs/f6k6ppv6' target="_blank">ppo_v1_seedNone_Jul13_181457</a></strong> to <a href='https://wandb.ai/ducks-riding-llamas/ride-those-llamas' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
# ...

# %%
# %matplotlib widget

# %%
# %run visualizer
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
